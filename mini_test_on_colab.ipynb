# %%
#only colab
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir("/content/gdrive/MyDrive/個別研究/車牌/LPRNet3")
# !ls
# !pip3 install efficientnet_pytorch
# !pip3 install torch==1.1.0 torchvision==0.3.0
# !pip3 install Pillow==8.0.0
# !nvcc --version
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#  data
#  Evaluation.py
# 'Evaluation.py 的副本'
#  LPRNet_continue_Train.py
#  LPRNet_Test.py
#  LPRNet_Train.py
# 'LPRNet_Train.py 的副本'
#  lpr_vali7747.ckpt
#  mini_LPRNet_continue_Train.py
#  mini_LPRNet_Train.py
# 'mini_saving_ckpt(1.1_0)'
# 'mini_saving_ckpt(1.1_-1)'
# 'mini_saving_ckpt(1.1_1)'
# 'mini_saving_ckpt(1.1_2)'
#  mini_test_on_colab.ipynb
#  mini_train_logging.txt
#  mini_validation_logging.txt
#  model
#  new
#  __pycache__
#  saving_ckpt
# 'saving_ckpt_1100epo(best151500_89.2_)'
# 'saving_ckpt_1600epo(best132000_90.2_)'
# 'saving_ckpt_450epo(best45500_87.4_)'
# 'saving_ckpt_new(1.1_0)_647epo(best063500_92.6_)'
# 'saving_ckpt_new(1.1_0)continue_1047epo(best083500_92.0_)'
# 'saving_ckpt_new2(1.1_1)_789epo(best90000_93.6_)'
# 'saving_ckpt_new2(1.1_2)_789epo(best79500_94.0 93.0 91.20_)'
# ...

# %%
# !python mini_LPRNet_Train.py
# !python mini_LPRNet_continue_Train.py
# Out:
# p: 3
# r: 1.3310000000000004
# device:  cuda:0
# len CHARS:  68
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2539: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 48, 29, 123]           1,344
#        BatchNorm2d-2          [-1, 48, 29, 123]              96
#               ReLU-3          [-1, 48, 29, 123]               0
#          MaxPool3d-4          [-1, 48, 27, 121]               0
#             Conv2d-5          [-1, 24, 27, 121]           1,176
#               ReLU-6          [-1, 24, 27, 121]               0
# ...

# %%
# !python Evaluation.py

# %%
2.449489742783178*2.449489742783178
